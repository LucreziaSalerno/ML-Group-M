# %%
# We import the necessary libraries 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# We load the needed datasets 
players = pd.read_csv("../data/player_profiles.csv", low_memory=False)
performances = pd.read_csv("../data/player_performances.zip", compression='zip')
market_values = pd.read_csv("../data/player_market_value.csv")
injuries = pd.read_csv("../data/player_injuries.csv")
teams = pd.read_csv("../data/team_details.csv")
transfers = pd.read_csv("../data/transfer_history.csv")
# Out:
# Could not save font_manager cache Lock error: Matplotlib failed to acquire the following lock file:
#     C:\Users\user\.matplotlib\fontlist-v390.json.matplotlib-lock
# This maybe due to another process holding this lock file.  If you are sure no
# other Matplotlib process is running, remove this file and try again.

# %%
market_values['date_unix'].head()
# Out:
# 0    2023-12-19
# 1    2024-06-23
# 2    2005-01-06
# 3    2008-06-03
# 4    2009-08-29
# Name: date_unix, dtype: object

# %%
# JOIN KEY
PLAYER_ID = 'player_id'

# AGGREGATE PERFORMANCE DATA
# We filter for recent seasons (from 2010 onwards) to focus on relevant data and reduce noise from very old performances
def extract_start_year(season):
# we have some seasons in format like '08/09'
    if '/' in season:
        year = season.split('/')[0]
        year = int(year)
        
        if year <= 30:   
            return 2000 + year
        else:            
            return 1900 + year
    
    # and some formatted like '1975'
    elif season.isdigit():
        return int(season)
    
    else:
        return None

performances['season_start_year'] = performances['season_name'].apply(extract_start_year)

performances = performances[
    performances['season_start_year'] >= 2010
]


# Aggregate performance stats per player
performance_agg = performances.groupby(PLAYER_ID).agg({
    'nb_on_pitch': 'sum',
    'goals': 'sum',
    'assists': 'sum',
    'minutes_played': 'sum',
    'yellow_cards': 'sum',
    'direct_red_cards': 'sum',
}).reset_index()

# Create derived features
performance_agg['goals_per_90'] = (performance_agg['goals'] / performance_agg['minutes_played'] * 90).round(2)
performance_agg['assists_per_90'] = (performance_agg['assists'] / performance_agg['minutes_played'] * 90).round(2)
performance_agg['goal_contributions'] = performance_agg['goals'] + performance_agg['assists']

# Handle division by zero
performance_agg['goals_per_90'] = performance_agg['goals_per_90'].fillna(0)
performance_agg['assists_per_90'] = performance_agg['assists_per_90'].fillna(0)

# We rename columns for clarity
performance_agg = performance_agg.rename(columns={
    'nb_on_pitch': 'matches',
    'direct_red_cards': 'red_cards'
})


# GET LATEST MARKET VALUE
market_values['date'] = pd.to_datetime(market_values['date_unix'])
market_values = market_values.sort_values('date')

# Get latest valuation per player
latest_values = (
    market_values
    .groupby(PLAYER_ID)
    .tail(1)
)

# Get first valuation per player
first_values = (
    market_values
    .groupby(PLAYER_ID)
    .head(1)
)

# Merge first and latest to compute growth
value_change = latest_values.merge(
    first_values[[PLAYER_ID, 'value']],
    on=PLAYER_ID,
    suffixes=('_latest', '_first'),
    how='left'
)

value_change['value_change_pct'] = (
    (value_change['value_latest'] - value_change['value_first']) /
    value_change['value_first'] * 100
).round(2)

# Attach value change to latest values
latest_values = latest_values.merge(
    value_change[[PLAYER_ID, 'value_change_pct']],
    on=PLAYER_ID,
    how='left'
)

# Rename target column
latest_values = latest_values.rename(
    columns={'value': 'current_market_value'})


# AGGREGATE INJURY DATA
injury_agg = injuries.groupby(PLAYER_ID).agg({
    'days_missed': 'sum',
    'injury_reason': 'count'
}).reset_index()

injury_agg = injury_agg.rename(columns={
    'days_missed': 'total_days_injured',
    'injury_reason': 'total_injuries'
})

# Create injury proneness score
injury_agg['injury_proneness'] = (injury_agg['total_injuries'] / 3).round(2)


# JOIN ALL DATAFRAMES
# Start with player profiles
df = players.copy()

# Join performance stats
df = df.merge(performance_agg, on=PLAYER_ID, how='left')

# Join market values (INNER JOIN - only keep players with valuations)
df = df.merge(
    latest_values[[PLAYER_ID, 'current_market_value', 'value_change_pct']], 
    on=PLAYER_ID, 
    how='inner'
)

# Join injury data
df = df.merge(injury_agg, on=PLAYER_ID, how='left')

# Fill missing injury data with 0
df['total_days_injured'] = df['total_days_injured'].fillna(0)
df['total_injuries'] = df['total_injuries'].fillna(0)
df['injury_proneness'] = df['injury_proneness'].fillna(0)

# Join team details
df = df.merge(
    teams[['club_id', 'competition_name', 'club_division']],
    left_on='current_club_id',
    right_on='club_id',
    how='left'
)

# Compute players age
today = pd.Timestamp.today()

df['date_of_birth'] = pd.to_datetime(df['date_of_birth'], errors='coerce')

df['age'] = (
    today.year - df['date_of_birth'].dt.year
    - (
        (today.month < df['date_of_birth'].dt.month) |
        (
            (today.month == df['date_of_birth'].dt.month) &
            (today.day < df['date_of_birth'].dt.day)
        )
    )
).astype('Int64')


# DATA CLEANING
# Define critical columns
critical_columns = ['current_market_value']
if 'age' in df.columns:
    critical_columns.append('age')
if 'position' in df.columns:
    critical_columns.append('position')

# Remove rows with missing critical data
df = df.dropna(subset=critical_columns)

# Remove players with zero market value
df = df[df['current_market_value'] > 0]

# Fill missing performance stats with 0
performance_cols = ['goals', 'assists', 'minutes_played', 'matches', 
                   'goals_per_90', 'assists_per_90', 'goal_contributions',
                   'yellow_cards', 'red_cards']

for col in performance_cols:
    if col in df.columns:
         df[col] = df[col].fillna(0)

# We drop columns that are not useful for modeling (like images, social media links, etc.)
cols_to_drop = [
    'player_slug',
    'player_image_url',
    'place_of_birth',
    'country_of_birth',
    'name_in_home_country',
    'social_media_url',
    'second_club_url',
    'third_club_url',
    'fourth_club_url',
    'player_agent_id',
    'player_agent_name',
    'club_id'
]

df = df.drop(columns = cols_to_drop)

# %%
print(df[['matches','goals','assists']].head())
# Out:
#     matches  goals  assists
# 4     401.0   44.0     35.0
# 8      62.0    2.0      4.0
# 9      43.0   10.0      2.0
# 10     60.0    8.0      0.0
# 11    107.0   21.0     18.0

# %%
print(f"Players with 0 minutes: {(df['minutes_played'] == 0).sum()}")
print(f"Players with 0 minutes but stats > 0: {((df['minutes_played'] == 0) & ((df['assists'] > 0) | (df['goals'] > 0))).sum()}")

zero_minutes_mask = df["minutes_played"] == 0

df.loc[zero_minutes_mask, [
    "goals", 
    "assists", 
    "yellow_cards", 
    "red_cards",
    "goals_per_90",
    "assists_per_90",
    "goal_contributions"
]] = 0

# Verify no more inf values
print(df[["goals","assists","yellow_cards","red_cards","goals_per_90","assists_per_90","goal_contributions"]].isin([np.inf, -np.inf]).sum())
# Out:
# Players with 0 minutes: 1350
# Players with 0 minutes but stats > 0: 687
# goals                 0
# assists               0
# yellow_cards          0
# red_cards             0
# goals_per_90          0
# assists_per_90        0
# goal_contributions    0
# dtype: int64

# %% [markdown]
# Out of 1,350 players with 0 minutes played, 687 presented non-zero performance statistics (goals, assists, and/or disciplinary cards), which is statistically impossible from a football standpoint. All performance metrics for these players were set to 0.
#
# It is worth noting that this decision carries an implicit assumption: disciplinary actions received outside of active play, such as cards issued to bench players for dissent, are treated as irrelevant to player evaluation. However, these incidents may reveal latent behavioural characteristics, such as competitiveness or temperament, that could meaningfully influence a player's market value and would otherwise go uncaptured by the model.

# %% [markdown]
# ## PCA Analysis

# %%
print(df.shape)
df.head()
# Out:
# (33557, 40)
#     player_id                   player_name date_of_birth  height  \
# 4      100001        Carlos Auzqui (100001)    1991-03-16   180.0
# 8     1000274        Brian Romero (1000274)    2006-05-11     0.0
# 9     1000273  Nimfasha Berchimas (1000273)    2008-02-22   172.0
# 10    1000135        Joselu Pérez (1000135)    2004-03-12   183.0
# 11    1000284            Jed Drew (1000284)    2003-08-29   176.0
#
#                citizenship  is_eu                 position main_position  \
# 4                Argentina  False    Attack - Right Winger        Attack
# 8    United States  Mexico  False    Attack - Right Winger        Attack
# 9   United States  Burundi  False     Attack - Left Winger        Attack
# 10                   Spain   True  Attack - Centre-Forward        Attack
# 11               Australia  False    Attack - Right Winger        Attack
#
#      foot  current_club_id  ... assists_per_90 goal_contributions  \
# ...

# %%
numeric_df = df.select_dtypes(include=[np.number]).copy()

print("Number of numeric features:", numeric_df.shape[1])
# Out:
# Number of numeric features: 19

# %%
cols_to_exclude = [
    'player_id',
    'current_club_id',
    'current_market_value'  # target-like variable
]

X = numeric_df.drop(columns=[col for col in cols_to_exclude if col in numeric_df.columns], errors='ignore')

# %%
# remove constant columns
X = X.loc[:, X.nunique() > 1]

# fill missing values
X = X.fillna(0)

# %%
# Keep only true numeric columns
X = X.select_dtypes(include=[np.number]).copy()

# Replace inf values with NaN, then fill
X = X.replace([np.inf, -np.inf], np.nan)
X = X.fillna(0)

# check data types
print(X.dtypes.value_counts())
print(X.shape)
# Out:
# float64    15
# Int64       1
# Name: count, dtype: int64
# (33557, 16)

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
pca = PCA()
X_pca = pca.fit_transform(X_scaled)

explained_variance = pca.explained_variance_ratio_
cumulative_variance = explained_variance.cumsum()

pca_summary = pd.DataFrame({
    'PC': [f'PC{i+1}' for i in range(len(explained_variance))],
    'Explained Variance': explained_variance,
    'Cumulative Variance': cumulative_variance
})

pca_summary.head(10)
# Out:
#      PC  Explained Variance  Cumulative Variance
# 0   PC1            0.348362             0.348362
# 1   PC2            0.152037             0.500399
# 2   PC3            0.105047             0.605446
# 3   PC4            0.063401             0.668847
# 4   PC5            0.061556             0.730404
# 5   PC6            0.059526             0.789930
# 6   PC7            0.055429             0.845358
# 7   PC8            0.042731             0.888089
# 8   PC9            0.035089             0.923178
# 9  PC10            0.023910             0.947088

# %%
# FIND NUMBER OF COMPONENTS FOR 80% AND 90%

n_components_80 = np.argmax(cumulative_variance >= 0.80) + 1
n_components_90 = np.argmax(cumulative_variance >= 0.90) + 1

print("Number of components explaining at least 80% variance:", n_components_80)
print("Number of components explaining at least 90% variance:", n_components_90)
# Out:
# Number of components explaining at least 80% variance: 7
# Number of components explaining at least 90% variance: 9

# %%
plt.figure(figsize=(8,5))
plt.plot(range(1, len(explained_variance)+1), explained_variance, marker='o')
plt.xlabel("Principal Component")
plt.ylabel("Explained Variance Ratio")
plt.title("Scree Plot")
plt.grid(True)
plt.show()

# %%
#CUMULATIVE EXPLAINED VARIANCE PLOT
plt.figure(figsize=(8,5))
plt.plot(range(1, len(cumulative_variance)+1), cumulative_variance, marker='o')
plt.axhline(y=0.80, linestyle='--')
plt.axhline(y=0.90, linestyle='--')
plt.xlabel("Principal Component")
plt.ylabel("Cumulative Explained Variance")
plt.title("Cumulative Explained Variance")
plt.grid(True)
plt.show()

# %%
pca_final = PCA(n_components=0.90)  # keep 90% variance
X_reduced = pca_final.fit_transform(X_scaled)

print("Original shape:", X.shape)
print("Reduced shape:", X_reduced.shape)
print("Number of components kept:", pca_final.n_components_)
# Out:
# Original shape: (33557, 16)
# Reduced shape: (33557, 9)
# Number of components kept: 9

# %%
loadings = pd.DataFrame(
    pca_final.components_.T,
    columns=[f'PC{i+1}' for i in range(pca_final.n_components_)],
    index=X.columns
)

loadings.head()
# Out:
#                            PC1       PC2       PC3       PC4       PC5  \
# height                0.111562 -0.111388 -0.031007  0.404861  0.224519
# on_loan_from_club_id -0.043967  0.049821  0.015394 -0.390609  0.907057
# matches               0.375542 -0.135116 -0.224150  0.040538  0.023733
# goals                 0.310534  0.347773 -0.121028  0.016441 -0.001769
# assists               0.331969  0.217490 -0.086562  0.038807  0.003477
#
#                            PC6       PC7       PC8       PC9
# height               -0.577106  0.626229 -0.045053 -0.157445
# on_loan_from_club_id -0.072038 -0.117492  0.020926 -0.002718
# matches              -0.005612 -0.136432  0.046141  0.027359
# goals                -0.038778 -0.066001 -0.349443 -0.041036
# assists               0.020240 -0.170065  0.175120 -0.485974

# %%
loadings['PC1'].abs().sort_values(ascending=False).head(10)
# Out:
# matches               0.375542
# goal_contributions    0.342170
# assists               0.331969
# goals                 0.310534
# total_injuries        0.308013
# injury_proneness      0.308011
# age                   0.304994
# yellow_cards          0.298589
# total_days_injured    0.222788
# minutes_played        0.185338
# Name: PC1, dtype: float64

# %%
# Show how much variance each PC explains
print(pca_summary.head(10))

# Key interpretation values
total_variance_80 = np.argmax(cumulative_variance >= 0.80) + 1
total_variance_90 = np.argmax(cumulative_variance >= 0.90) + 1

print(f"Number of components to explain 80% variance: {total_variance_80}")
print(f"Number of components to explain 90% variance: {total_variance_90}")
# Out:
#      PC  Explained Variance  Cumulative Variance
# 0   PC1            0.348362             0.348362
# 1   PC2            0.152037             0.500399
# 2   PC3            0.105047             0.605446
# 3   PC4            0.063401             0.668847
# 4   PC5            0.061556             0.730404
# 5   PC6            0.059526             0.789930
# 6   PC7            0.055429             0.845358
# 7   PC8            0.042731             0.888089
# 8   PC9            0.035089             0.923178
# 9  PC10            0.023910             0.947088
# Number of components to explain 80% variance: 7
# Number of components to explain 90% variance: 9

# %%
# 2D PCA projection
pca_2 = PCA(n_components=2)
X_pca_2 = pca_2.fit_transform(X_scaled)

plt.figure()
plt.scatter(X_pca_2[:,0], X_pca_2[:,1], alpha=0.6)
plt.xlabel("PC1")
plt.ylabel("PC2")
plt.title("Players projected on first two principal components")
plt.grid()
plt.show()

# %% [markdown]
# PCA was used to reduce the dimensionality of the player valuation dataset while preserving as much information as possible.
#
# Since the variables were measured on different scales, the data was standardized before applying PCA.
#
# The results showed that the first principal components explained a large proportion of the total variance, meaning that the original dataset can be summarized with fewer dimensions.
#
# The scree plot and cumulative explained variance confirmed that only a limited number of components were needed to retain most of the information. By examining the loadings, it was also possible to identify which original variables contributed most strongly to the first components.
#
# Overall, PCA simplified the structure of the dataset and created a reduced representation that can be useful for later modeling or clustering.

# %% [markdown]
# ## Feature Engineering

# %% [markdown]
# AI assistance provided by Claude (Anthropic, 2026), used as a development aid for code debugging, feature engineering decisions, and data quality analysis. All implementation decisions were reviewed and validated by the team.

# %%
# Positional encoding
print(f"Previous type: {df["main_position"].dtype}")
df["main_position"] = pd.Categorical(df["main_position"], categories=["Goalkeeper", "Defender", "Midfield", "Attack"], ordered=False)
print(f"New type: {df["main_position"].dtype}")
print(df["main_position"].cat.categories)
# Out:
# Previous type: object
# New type: category
# Index(['Goalkeeper', 'Defender', 'Midfield', 'Attack'], dtype='object')

# %%
# Age-related features
# Age squared
df["age_squared"] = df["age"]**2

# Youth, Prime and Veteran
position_age_bins = {
    "Goalkeeper": [0, 23, 32, np.inf],
    "Defender":   [0, 22, 30, np.inf],
    "Midfield":   [0, 23, 29, np.inf],
    "Attack":     [0, 22, 28, np.inf],
}

def assign_career_phase(row):
    position = row["main_position"]
    age = row["age"]
    
    if pd.isna(position) or pd.isna(age):
        return None
    
    bins = position_age_bins.get(position)
    if bins is None:
        return None
    
    if age <= bins[1]:
        return "Youth"
    elif age <= bins[2]:
        return "Prime"
    else:
        return "Veteran"

df["career_phase"] = df.apply(assign_career_phase, axis=1)

df["career_phase"] = pd.Categorical(
    df["career_phase"],
    categories=["Veteran", "Youth", "Prime"],
    ordered=False
)

print(df["career_phase"].value_counts())
# Out:
# career_phase
# Prime      15910
# Veteran     9309
# Youth       8338
# Name: count, dtype: int64

# %% [markdown]
# Important assumption: Players without a valid contract (lower than 0 years under contract) were assumed free agents.

# %%
# Contract-related features
# Years left under contract
df["contract_expires"] = pd.to_datetime(df["contract_expires"])
df["years_under_contract"] = (df["contract_expires"] - pd.Timestamp.now()).dt.days / 365.00

# Clip negative values to 0
df.loc[df["years_under_contract"] < 0, "years_under_contract"] = 0

# Create free_agent boolean column
df["free_agent"] = df["years_under_contract"] == 0

# Set years_under_contract NaN to 0 for consistency
df["years_under_contract"] = df["years_under_contract"].fillna(0)

# Print percentage of free agents
print(f"Percentage of free agents: {df['free_agent'].mean() * 100:.2f}%")

# Ambiguous players
ambiguous= (
    df["competition_name"].isnull() & 
    df["contract_expires"].isnull() & 
    (df["free_agent"] == False)
)

print(f"Ambiguous players being marked as free agents: {ambiguous.sum()}")

print(f"Free agents before: {df["free_agent"].sum()}")

# Turning them into free agents and no contract available
df.loc[ambiguous, "free_agent"] = True
df.loc[ambiguous, "years_under_contract"] = 0

print(f"Free agents after: {df['free_agent'].sum()}")
print(f"Percentage of free agents: {df['free_agent'].mean() * 100:.2f}%")
# Out:
# Percentage of free agents: 11.71%
# Ambiguous players being marked as free agents: 3900
# Free agents before: 3930
# Free agents after: 7830
# Percentage of free agents: 23.33%

# %% [markdown]
# A subset of 3,900 players were identified as ambiguous cases, players not initially flagged as free agents, but with no recorded contract expiry date and no associated competition. Since the absence of both a contract and a league affiliation provides no evidence of an active contractual relationship, these players were reclassified as free agents. Their years_under_contract was set to 0, consistent with the free agent definition used throughout the dataset.

# %%
# League Quality feature

league_quality_map = {
    # Tier 5 - Elite
    "Premier League": 5,
    "Serie A": 5,
    "LaLiga": 5,
    "Bundesliga": 5,
    "Ligue 1": 5,
    
    # Tier 4 - Very Strong
    "Pro League": 4,
    "Liga Portugal": 4,
    "Championship": 4,
    "Eredivisie": 4,
    "Scottish Premiership": 4,
    "Jupiler Pro League": 4,
    "Süper Lig": 4,
    "PKO BP Ekstraklasa": 4,
    "Eliteserien": 4,
    "Allsvenskan": 4,
    "Superliga": 4,
    "K League 1": 4,
    "Major League Soccer": 4,
    "Campeonato Brasileiro Série A": 4,
    "Chinese Super League": 4,
    "Qatar Stars League": 4,
    "Super Lig": 4,
    "Super League 1": 4,
    "Première Liga": 4,

    # Tier 3 - Strong (second divisions + strong regional)
    "Süper Lig 2": 3,
    "Pro League 2": 3,
    "2. Bundesliga": 3,
    "LaLiga2": 3,
    "Serie B": 3,
    "Ligue 2": 3,
    "Liga Portugal 2": 3,
    "League One": 3,
    "Scottish Championship": 3,
    "Keuken Kampioen Divisie": 3,
    "Superettan": 3,
    "OBOS-ligaen": 3,
    "1.Lig": 3,
    "Chance Liga": 3,
    "Niké Liga": 3,
    "Nemzeti Bajnokság": 3,
    "J1 League": 3,
    "J2 League": 3,
    "Liga MX Apertura": 3,
    "MLS Next Pro": 3,
    "A-League Men": 3,
    "Campeonato Brasileiro Série B": 3,
    "Primera Nacional": 3,
    "Torneo Clausura": 3,
    "SuperSport HNL": 3,
    "Prva Nogometna Liga": 3,
    "Challenger Pro League": 3,
    "Super League": 3,
    "Betclic 1 Liga": 3,
    "Persha Liga": 3,
    "Premier Liga": 3,
    "Challenge League": 3,
    "2. Liga": 3,
    "1.Division": 3,

    # Tier 2 - Average (third divisions + weaker national leagues)
    "Süper Lig 3": 2,
    "3. Liga": 2,
    "League Two": 2,
    "Scottish League One": 2,
    "Serie C - Girone A": 2,
    "Serie C - Girone B": 2,
    "Serie C - Girone C": 2,
    "Championnat National": 2,
    "Championnat National 2 - Groupe A": 2,
    "Championnat National 2 - Groupe B": 2,
    "Championnat National 2 - Groupe C": 2,
    "Primera Federación - Grupo I": 2,
    "Primera Federación - Grupo II": 2,
    "Regionalliga Bayern": 2,
    "Regionalliga West": 2,
    "Regionalliga Südwest": 2,
    "Regionalliga Nord": 2,
    "Regionalliga Northeast": 2,
    "USL Championship": 2,
    "Liga de Expansión MX Clausura": 2,
    "China League One": 2,
    "J3 League": 2,
    "Nemzeti Bajnokság II.": 2,
    "Super League 2": 2,
    "Betclic 2 Liga": 2,
    "2.Lig Kirmizi": 2,
    "2.Lig Beyaz": 2,
    "Chance Narodni Liga": 2,
    "MONACObet liga": 2,
    "Promotion League": 2,
    "National League": 2,
    "K League 2": 2,
    "Qatari Second Division": 2,
    "USL League One": 2,
    "1ste Nationale VV": 2,
    "1ste Nationale ACFF": 2,
    "2de Nationale VV A": 2,
    "2de Nationale VV B": 2,
    "Ettan Norra": 2,
    "2.Division": 2,

    # Tier 1 - Weak (fourth divisions and below, youth, amateur)
    "Serie D - Girone A": 1,
    "Serie D - Girone B": 1,
    "Serie D - Girone C": 1,
    "Serie D - Girone D": 1,
    "Serie D - Girone E": 1,
    "Serie D - Girone F": 1,
    "Serie D - Girone G": 1,
    "Serie D - Girone H": 1,
    "Serie D - Girone I": 1,
    "Championnat National 3 - Groupe A": 1,
    "Championnat National 3 - Groupe B": 1,
    "Championnat National 3 - Groupe C": 1,
    "Championnat National 3 - Groupe E": 1,
    "Championnat National 3 - Groupe F": 1,
    "Championnat National 3 - Groupe G": 1,
    "Championnat National 3 - Groupe H": 1,
    "Segunda Federación - Grupo I": 1,
    "Segunda Federación - Grupo II": 1,
    "Segunda Federación - Grupo III": 1,
    "Segunda Federación - Grupo IV": 1,
    "Segunda Federación - Grupo V": 1,
    "Primavera 1": 1,
    "Primavera 2 - A": 1,
    "Primavera 2 - B": 1,
    "Premier League 2": 1,
    "Liga Revelação U23": 1,
    "U21 Division 1 Fall": 1,
    "U21 Division 2 Fall": 1,
    "1. Liga Classic group 2": 1,
    "3.Lig Grup 1": 1,
    "3.Lig Grup 2": 1,
    "3.Lig Grup 3": 1,
    "3.Lig Grup 4": 1,
    "Liga 3": 1,
    "National League South": 1,
    "Federal A - Fase Reválida": 1,
    "Federal A - Fase Campeonato": 1,
    "Campeonato de Portugal - Série A": 1,
    "Campeonato de Portugal - Série B": 1,
    "Campeonato Paulista": 1,
}

# Normalize all historical names to one canonical name
league_name_map = {
    # Portugal
    "Betclic 1 Liga": "Liga Portugal",
    "Betclic 2 Liga": "Liga Portugal 2",

    # Germany
    "1. Bundesliga": "Bundesliga",

    # Belgium
    "Jupiler Pro League": "Pro League",
    "Challenger Pro League": "Pro League 2",

    # Turkey
    "1.Lig": "Süper Lig 2",
    "2.Lig Kirmizi": "Süper Lig 3",
    "2.Lig Beyaz": "Süper Lig 3",

}

df["competition_name"] = df["competition_name"].replace(league_name_map)

# Apply quality map on the normalized column, this treats unknown leagues as 1
df["league_quality"] = df["competition_name"].map(league_quality_map).fillna(1)

print(f"Number of players with Unknown League and Free Agent: {len(df[(df['competition_name'].isnull())&(df["free_agent"]==True)])}")
print(f"Number of players with Unknown League and NOT Free Agent: {len(df[(df['competition_name'].isnull())&(df["free_agent"]==False)])}")

# Overwrites free agents' league quality with 0
df.loc[df["free_agent"] == True, "league_quality"] = 0
# Out:
# Number of players with Unknown League and Free Agent: 4934
# Number of players with Unknown League and NOT Free Agent: 4767

# %%
# Relative to team value feature
# Calculate club totals
club_totals = df.groupby("current_club_name")["current_market_value"].transform("sum")

# Assign relative market value
df["relative_market_value"] = df["current_market_value"] / club_totals

# Free agents have no club, so set to 0
df.loc[df["free_agent"], "relative_market_value"] = 0

# %%
# Performance indicators features
# G/A (Goal Contributions) per 90
df["G/A_per_90"] = df["goals_per_90"] + df["assists_per_90"]

# Cards per 90
df["cards_per_90"] = (df["yellow_cards"] + 2 * df["red_cards"]) / (df["minutes_played"] * 90)

# Handle Missing Values
df["cards_per_90"] = df["cards_per_90"].fillna(0)

# Net Performance per 90
df["net_per_90"] = df["G/A_per_90"] - df["cards_per_90"]

# Normalize within position groups using z-score
df["net_per_90_normalized"] = df.groupby("main_position")["net_per_90"].transform(
    lambda x: (x - x.mean()) / x.std()
)

df.loc[df["competition_name"]=="LaLiga",["net_per_90_normalized","player_name","position","competition_name"]].sort_values(by="net_per_90_normalized",ascending=False)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_1092\3893739009.py:15: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df["net_per_90_normalized"] = df.groupby("main_position")["net_per_90"].transform(
#        net_per_90_normalized                 player_name  \
# 50881              13.576595   Beñat Turrientes (634431)
# 29332               5.821979  Robert Lewandowski (38253)
# 22132               5.616109      Kylian Mbappé (342229)
# 29890               4.863816        Mateu Morey (388513)
# 2105                3.923591       Carlos Espí (1063338)
# ...                      ...                         ...
# 44204              -1.100649      Germán Valera (548188)
# 54344              -1.123536     Ilias Akhomach (709969)
# 50003              -1.131165         Fran Pérez (622988)
# ...

# %%
# Interaction Terms
# G/A Normalized X League Quality
df["goal_contributions_normalized"] = df.groupby("main_position")["goal_contributions"].transform(
    lambda x: (x - x.mean()) / x.std()
)
df["G/A_normalized_X_league_quality"] = df["goal_contributions_normalized"] * df["league_quality"]

# Age X Position
df["age_X_position"] = (
    df["career_phase"].astype(object) + "_" + df["main_position"].astype(object)
)
df["age_X_position"] = pd.Categorical(df["age_X_position"])
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_1092\2636627879.py:3: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df["goal_contributions_normalized"] = df.groupby("main_position")["goal_contributions"].transform(

# %%
# SAVE DATASET
df.to_csv("player_valuation_dataset.csv", index=False)

# Display summary
print(f"Dataset created: {len(df):,} players × {len(df.columns)} columns")
print(f"\nSample data:")
print(df.head())
print(f"\nBasic statistics:")
print(df[['current_market_value', 'goals', 'assists', 'age']].describe())
# Out:
# Dataset created: 33,557 players × 53 columns
#
# Sample data:
#     player_id                   player_name date_of_birth  height  \
# 4      100001        Carlos Auzqui (100001)    1991-03-16   180.0
# 8     1000274        Brian Romero (1000274)    2006-05-11     0.0
# 9     1000273  Nimfasha Berchimas (1000273)    2008-02-22   172.0
# 10    1000135        Joselu Pérez (1000135)    2004-03-12   183.0
# 11    1000284            Jed Drew (1000284)    2003-08-29   176.0
#
#                citizenship  is_eu                 position main_position  \
# 4                Argentina  False    Attack - Right Winger        Attack
# 8    United States  Mexico  False    Attack - Right Winger        Attack
# 9   United States  Burundi  False     Attack - Left Winger        Attack
# 10                   Spain   True  Attack - Centre-Forward        Attack
# 11               Australia  False    Attack - Right Winger        Attack
#
#      foot  current_club_id  ... free_agent league_quality  \
# ...
