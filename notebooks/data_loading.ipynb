# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

players = pd.read_csv("../data/player_profiles.csv")
performances = pd.read_csv("../data/player_performances.zip", compression='zip')
market_values = pd.read_csv("../data/player_market_value.csv")
injuries = pd.read_csv("../data/player_injuries.csv")
teams = pd.read_csv("../data/team_details.csv")
transfers = pd.read_csv("../data/transfer_history.csv")
# Out:
# /var/folders/0t/s4vmj84915scl6tf65t44y_w0000gn/T/ipykernel_99876/1939850787.py:5: DtypeWarning: Columns (0: third_club_url, 1: third_club_name, 2: fourth_club_url, 3: fourth_club_name) have mixed types. Specify dtype option on import or set low_memory=False.
#   players = pd.read_csv("../data/player_profiles.csv")

# %%
print("PLAYERS:")
print(players.columns.tolist())

print("\nPERFORMANCES:")
print(performances.columns.tolist())

print("\nMARKET VALUES:")
print(market_values.columns.tolist())

print("\nINJURIES:")
print(injuries.columns.tolist())

print("\nTEAMS:")
print(teams.columns.tolist())

print("\nTRANSFERS:")
print(transfers.columns.tolist())
# Out:
# PLAYERS:
# ['player_id', 'player_slug', 'player_name', 'player_image_url', 'name_in_home_country', 'date_of_birth', 'place_of_birth', 'country_of_birth', 'height', 'citizenship', 'is_eu', 'position', 'main_position', 'foot', 'current_club_id', 'current_club_name', 'joined', 'contract_expires', 'outfitter', 'social_media_url', 'player_agent_id', 'player_agent_name', 'contract_option', 'date_of_last_contract_extension', 'on_loan_from_club_id', 'on_loan_from_club_name', 'contract_there_expires', 'second_club_url', 'second_club_name', 'third_club_url', 'third_club_name', 'fourth_club_url', 'fourth_club_name', 'date_of_death']
#
# PERFORMANCES:
# ['player_id', 'season_name', 'competition_id', 'competition_name', 'team_id', 'team_name', 'nb_in_group', 'nb_on_pitch', 'goals', 'assists', 'own_goals', 'subed_in', 'subed_out', 'yellow_cards', 'second_yellow_cards', 'direct_red_cards', 'penalty_goals', 'minutes_played', 'goals_conceded', 'clean_sheets']
#
# MARKET VALUES:
# ['player_id', 'date_unix', 'value']
#
# INJURIES:
# ['player_id', 'season_name', 'injury_reason', 'from_date', 'end_date', 'days_missed', 'games_missed']
#
# TEAMS:
# ['club_id', 'club_slug', 'club_name', 'logo_url', 'country_name', 'season_id', 'competition_id', 'competition_slug', 'competition_name', 'club_division', 'source_url', '_last_modified_at']
#
# TRANSFERS:
# ['player_id', 'season_name', 'transfer_date', 'from_team_id', 'from_team_name', 'to_team_id', 'to_team_name', 'transfer_type', 'value_at_transfer', 'transfer_fee']

# %%
# JOIN KEY

PLAYER_ID = 'player_id'

# AGGREGATE PERFORMANCE DATA
if 'season_name' in performances.columns:
    latest_season = performances['season_name'].max()
    performances_recent = performances[performances['season_name'] == latest_season]
else:
    performances_recent = performances

# Aggregate performance stats per player
performance_agg = performances_recent.groupby(PLAYER_ID).agg({
    'nb_on_pitch': 'sum',
    'goals': 'sum',
    'assists': 'sum',
    'minutes_played': 'sum',
    'yellow_cards': 'sum',
    'direct_red_cards': 'sum',
}).reset_index()

# Create derived features
performance_agg['goals_per_90'] = (performance_agg['goals'] / performance_agg['minutes_played'] * 90).round(2)
performance_agg['assists_per_90'] = (performance_agg['assists'] / performance_agg['minutes_played'] * 90).round(2)
performance_agg['goal_contributions'] = performance_agg['goals'] + performance_agg['assists']

# Handle division by zero
performance_agg['goals_per_90'].fillna(0, inplace=True)
performance_agg['assists_per_90'].fillna(0, inplace=True)


# GET LATEST MARKET VALUE
market_values['date'] = pd.to_datetime(
    market_values['date_unix'], unit='s'
)
market_values = market_values.sort_values('date')

# Get latest valuation per player
latest_values = (
    market_values
    .groupby(PLAYER_ID)
    .tail(1)
)

# Get first valuation per player
first_values = (
    market_values
    .groupby(PLAYER_ID)
    .head(1)
)

# Merge first and latest to compute growth
value_change = latest_values.merge(
    first_values[[PLAYER_ID, 'value']],
    on=PLAYER_ID,
    suffixes=('_latest', '_first'),
    how='left'
)

value_change['value_change_pct'] = (
    (value_change['value_latest'] - value_change['value_first']) /
    value_change['value_first'] * 100
).round(2)

# Attach value change to latest values
latest_values = latest_values.merge(
    value_change[[PLAYER_ID, 'value_change_pct']],
    on=PLAYER_ID,
    how='left'
)

# Rename target column
latest_values = latest_values.rename(
    columns={'value': 'current_market_value'})


# AGGREGATE INJURY DATA
injury_agg = injuries.groupby(PLAYER_ID).agg({
    'days_missed': 'sum',
    'injury_reason': 'count'
}).reset_index()

injury_agg = injury_agg.rename(columns={
    'days_missed': 'total_days_injured',
    'injury_reason': 'total_injuries'
})

# Create injury proneness score
injury_agg['injury_proneness'] = (injury_agg['total_injuries'] / 3).round(2)


# JOIN ALL DATAFRAMES
# Start with player profiles
df = players.copy()

# Join performance stats
df = df.merge(performance_agg, on=PLAYER_ID, how='left')

# Join market values (INNER JOIN - only keep players with valuations)
df = df.merge(
    latest_values[[PLAYER_ID, 'current_market_value', 'value_change_pct']], 
    on=PLAYER_ID, 
    how='inner'
)

# Join injury data
df = df.merge(injury_agg, on=PLAYER_ID, how='left')

# Fill missing injury data with 0
df['total_days_injured'].fillna(0, inplace=True)
df['total_injuries'].fillna(0, inplace=True)
df['injury_proneness'].fillna(0, inplace=True)

# Join team details
df = df.merge(
    teams[['club_id', 'competition_name', 'club_division']],
    left_on='current_club_id',
    right_on='club_id',
    how='left'
)

# Compute players age
today = pd.Timestamp.today()
df['date_of_birth'] = pd.to_datetime(df['date_of_birth'], errors='coerce')
df['age'] = ((today - df['date_of_birth']).dt.days / 365.25).astype(float)

# DATA CLEANING
# Define critical columns
critical_columns = ['current_market_value']
if 'age' in df.columns:
    critical_columns.append('age')
if 'position' in df.columns:
    critical_columns.append('position')

# Remove rows with missing critical data
df = df.dropna(subset=critical_columns)

# Remove players with zero market value
df = df[df['current_market_value'] > 0]

# Fill missing performance stats with 0
performance_cols = ['goals', 'assists', 'minutes_played', 'matches', 
                   'goals_per_90', 'assists_per_90', 'goal_contributions',
                   'yellow_cards', 'red_cards']

for col in performance_cols:
    if col in df.columns:
        df[col].fillna(0, inplace=True)


# SAVE DATASET

df.to_csv("player_valuation_dataset.csv", index=False)

# Display summary
print(f"Dataset created: {len(df):,} players × {len(df.columns)} columns")
print(f"\nSample data:")
print(df.head())
print(f"\nBasic statistics:")
print(df[['current_market_value', 'goals', 'assists', 'age']].describe())
# Out:
# /var/folders/0t/s4vmj84915scl6tf65t44y_w0000gn/T/ipykernel_99876/909846290.py:28: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   performance_agg['goals_per_90'].fillna(0, inplace=True)
# /var/folders/0t/s4vmj84915scl6tf65t44y_w0000gn/T/ipykernel_99876/909846290.py:29: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   performance_agg['assists_per_90'].fillna(0, inplace=True)
# /var/folders/0t/s4vmj84915scl6tf65t44y_w0000gn/T/ipykernel_99876/909846290.py:110: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   df['total_days_injured'].fillna(0, inplace=True)
# /var/folders/0t/s4vmj84915scl6tf65t44y_w0000gn/T/ipykernel_99876/909846290.py:111: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   df['total_injuries'].fillna(0, inplace=True)
# /var/folders/0t/s4vmj84915scl6tf65t44y_w0000gn/T/ipykernel_99876/909846290.py:112: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   df['injury_proneness'].fillna(0, inplace=True)
# /var/folders/0t/s4vmj84915scl6tf65t44y_w0000gn/T/ipykernel_99876/909846290.py:148: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   df[col].fillna(0, inplace=True)
# Dataset created: 33,557 players × 52 columns
#
# Sample data:
#     player_id         player_slug                   player_name  \
# 4      100001       carlos-auzqui        Carlos Auzqui (100001)
# 8     1000274        brian-romero        Brian Romero (1000274)
# 9     1000273  nimfasha-berchimas  Nimfasha Berchimas (1000273)
# 10    1000135        joselu-perez        Joselu Pérez (1000135)
# 11    1000284            jed-drew            Jed Drew (1000284)
#
#                                      player_image_url  \
# 4   https://img.a.transfermarkt.technology/portrai...
# 8   https://img.a.transfermarkt.technology/portrai...
# 9   https://img.a.transfermarkt.technology/portrai...
# 10  https://img.a.transfermarkt.technology/portrai...
# 11  https://img.a.transfermarkt.technology/portrai...
#
#        name_in_home_country date_of_birth           place_of_birth  \
# 4      Carlos Daniel Auzqui    1991-03-16               Longchamps
# 8      Brian Carmona Romero    2006-05-11  Concord, North Carolina
# 9                       NaN    2008-02-22                      NaN
# 10  José Luis Pérez del Amo    2004-03-12              Villalbilla
# 11         Jed Francis Drew    2003-08-29                 Canberra
#
#    country_of_birth  height             citizenship  ...  goal_contributions  \
# 4         Argentina   180.0               Argentina  ...                 NaN
# 8     United States     0.0   United States  Mexico  ...                 NaN
# 9               NaN   172.0  United States  Burundi  ...                 NaN
# 10            Spain   183.0                   Spain  ...                 NaN
# 11        Australia   176.0               Australia  ...                 NaN
#
#    current_market_value value_change_pct total_days_injured  total_injuries  \
# 4              200000.0           100.00                NaN             NaN
# 8              150000.0             0.00                NaN             NaN
# 9              400000.0           -20.00              206.0             1.0
# 10             100000.0           300.00                NaN             NaN
# 11             550000.0           266.67               40.0             3.0
#
#    injury_proneness  club_id     competition_name        club_division  \
# 4               NaN  14554.0      Torneo Clausura      Torneo Clausura
# 8               NaN  78435.0  Major League Soccer  Major League Soccer
# 9              0.33  78435.0  Major League Soccer  Major League Soccer
# 10              NaN      NaN                  NaN                  NaN
# 11             1.00   4467.0           Bundesliga           Bundesliga
#
#           age
# 4   34.959617
# 8   19.805613
# 9   18.020534
# 10  21.968515
# 11  22.505133
#
# [5 rows x 52 columns]
#
# Basic statistics:
#        current_market_value      goals    assists           age
# count          3.355700e+04  13.000000  13.000000  33557.000000
# mean           1.575363e+06   1.538462   0.538462     27.241222
# std            6.143874e+06   2.601775   1.050031      4.848939
# min            1.000000e+04   0.000000   0.000000     16.594114
# 25%            1.000000e+05   0.000000   0.000000     23.359343
# 50%            2.500000e+05   0.000000   0.000000     26.781656
# 75%            7.000000e+05   2.000000   0.000000     30.743326
# max            2.000000e+08   9.000000   3.000000     59.008898

# %%
# JOIN KEY

PLAYER_ID = 'player_id'

# AGGREGATE PERFORMANCE DATA
if 'season_name' in performances.columns:
    latest_season = performances['season_name'].max()
    performances_recent = performances[performances['season_name'] == latest_season]
else:
    performances_recent = performances

# Aggregate performance stats per player
performance_agg = performances_recent.groupby(PLAYER_ID).agg({
    'nb_on_pitch': 'sum',
    'goals': 'sum',
    'assists': 'sum',
    'minutes_played': 'sum',
    'yellow_cards': 'sum',
    'direct_red_cards': 'sum',
}).reset_index()

# Create derived features
performance_agg['goals_per_90'] = (performance_agg['goals'] / performance_agg['minutes_played'] * 90).round(2)
performance_agg['assists_per_90'] = (performance_agg['assists'] / performance_agg['minutes_played'] * 90).round(2)
performance_agg['goal_contributions'] = performance_agg['goals'] + performance_agg['assists']

# Handle division by zero
performance_agg['goals_per_90'].fillna(0, inplace=True)
performance_agg['assists_per_90'].fillna(0, inplace=True)


# GET LATEST MARKET VALUE
market_values['date'] = pd.to_datetime(
    market_values['date_unix'], unit='s'
)
market_values = market_values.sort_values('date')

# Get latest valuation per player
latest_values = (
    market_values
    .groupby(PLAYER_ID)
    .tail(1)
)

# Get first valuation per player
first_values = (
    market_values
    .groupby(PLAYER_ID)
    .head(1)
)

# Merge first and latest to compute growth
value_change = latest_values.merge(
    first_values[[PLAYER_ID, 'value']],
    on=PLAYER_ID,
    suffixes=('_latest', '_first'),
    how='left'
)

value_change['value_change_pct'] = (
    (value_change['value_latest'] - value_change['value_first']) /
    value_change['value_first'] * 100
).round(2)

# Attach value change to latest values
latest_values = latest_values.merge(
    value_change[[PLAYER_ID, 'value_change_pct']],
    on=PLAYER_ID,
    how='left'
)

# Rename target column
latest_values = latest_values.rename(
    columns={'value': 'current_market_value'})


# AGGREGATE INJURY DATA
injury_agg = injuries.groupby(PLAYER_ID).agg({
    'days_missed': 'sum',
    'injury_reason': 'count'
}).reset_index()

injury_agg = injury_agg.rename(columns={
    'days_missed': 'total_days_injured',
    'injury_reason': 'total_injuries'
})

# Create injury proneness score
injury_agg['injury_proneness'] = (injury_agg['total_injuries'] / 3).round(2)


# JOIN ALL DATAFRAMES
# Start with player profiles
df = players.copy()

# Join performance stats
df = df.merge(performance_agg, on=PLAYER_ID, how='left')

# Join market values (INNER JOIN - only keep players with valuations)
df = df.merge(
    latest_values[[PLAYER_ID, 'current_market_value', 'value_change_pct']], 
    on=PLAYER_ID, 
    how='inner'
)

# Join injury data
df = df.merge(injury_agg, on=PLAYER_ID, how='left')

# Fill missing injury data with 0
df['total_days_injured'].fillna(0, inplace=True)
df['total_injuries'].fillna(0, inplace=True)
df['injury_proneness'].fillna(0, inplace=True)

# Join team details if team_id exists
if 'team_id' in df.columns and 'team_id' in teams.columns:
    team_cols = ['team_id']
    if 'league' in teams.columns:
        team_cols.append('league')
    if 'team_market_value' in teams.columns:
        team_cols.append('team_market_value')
    
    df = df.merge(teams[team_cols], on='team_id', how='left')


# DATA CLEANING
# Define critical columns
critical_columns = ['current_market_value']
if 'age' in df.columns:
    critical_columns.append('age')
if 'position' in df.columns:
    critical_columns.append('position')

# Remove rows with missing critical data
df = df.dropna(subset=critical_columns)

# Remove players with zero market value
df = df[df['current_market_value'] > 0]

# Fill missing performance stats with 0
performance_cols = ['goals', 'assists', 'minutes_played', 'matches', 
                   'goals_per_90', 'assists_per_90', 'goal_contributions',
                   'yellow_cards', 'red_cards']

for col in performance_cols:
    if col in df.columns:
        df[col].fillna(0, inplace=True)


# SAVE DATASET

df.to_csv("player_valuation_dataset.csv", index=False)

# Display summary
print(f"Dataset created: {len(df):,} players × {len(df.columns)} columns")
print(f"\nSample data:")
print(df.head())
print(f"\nBasic statistics:")
print(df[['current_market_value', 'goals', 'assists', 'age']].describe())
# Out:
# /var/folders/0t/s4vmj84915scl6tf65t44y_w0000gn/T/ipykernel_99876/405930370.py:28: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   performance_agg['goals_per_90'].fillna(0, inplace=True)
# /var/folders/0t/s4vmj84915scl6tf65t44y_w0000gn/T/ipykernel_99876/405930370.py:29: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   performance_agg['assists_per_90'].fillna(0, inplace=True)
# /var/folders/0t/s4vmj84915scl6tf65t44y_w0000gn/T/ipykernel_99876/405930370.py:110: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   df['total_days_injured'].fillna(0, inplace=True)
# /var/folders/0t/s4vmj84915scl6tf65t44y_w0000gn/T/ipykernel_99876/405930370.py:111: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   df['total_injuries'].fillna(0, inplace=True)
# /var/folders/0t/s4vmj84915scl6tf65t44y_w0000gn/T/ipykernel_99876/405930370.py:112: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   df['injury_proneness'].fillna(0, inplace=True)
# /var/folders/0t/s4vmj84915scl6tf65t44y_w0000gn/T/ipykernel_99876/405930370.py:146: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   df[col].fillna(0, inplace=True)
# Dataset created: 33,590 players × 48 columns
#
# Sample data:
#     player_id         player_slug                   player_name  \
# 4      100001       carlos-auzqui        Carlos Auzqui (100001)
# 8     1000274        brian-romero        Brian Romero (1000274)
# 9     1000273  nimfasha-berchimas  Nimfasha Berchimas (1000273)
# 10    1000135        joselu-perez        Joselu Pérez (1000135)
# 11    1000284            jed-drew            Jed Drew (1000284)
#
#                                      player_image_url  \
# 4   https://img.a.transfermarkt.technology/portrai...
# 8   https://img.a.transfermarkt.technology/portrai...
# 9   https://img.a.transfermarkt.technology/portrai...
# 10  https://img.a.transfermarkt.technology/portrai...
# 11  https://img.a.transfermarkt.technology/portrai...
#
#        name_in_home_country date_of_birth           place_of_birth  \
# 4      Carlos Daniel Auzqui    1991-03-16               Longchamps
# 8      Brian Carmona Romero    2006-05-11  Concord, North Carolina
# 9                       NaN    2008-02-22                      NaN
# 10  José Luis Pérez del Amo    2004-03-12              Villalbilla
# 11         Jed Francis Drew    2003-08-29                 Canberra
#
#    country_of_birth  height             citizenship  ...  yellow_cards  \
# 4         Argentina   180.0               Argentina  ...           NaN
# 8     United States     0.0   United States  Mexico  ...           NaN
# 9               NaN   172.0  United States  Burundi  ...           NaN
# 10            Spain   183.0                   Spain  ...           NaN
# 11        Australia   176.0               Australia  ...           NaN
#
#    direct_red_cards goals_per_90 assists_per_90  goal_contributions  \
# 4               NaN          NaN            NaN                 NaN
# 8               NaN          NaN            NaN                 NaN
# 9               NaN          NaN            NaN                 NaN
# 10              NaN          NaN            NaN                 NaN
# 11              NaN          NaN            NaN                 NaN
#
#    current_market_value value_change_pct total_days_injured total_injuries  \
# 4              200000.0           100.00                NaN            NaN
# 8              150000.0             0.00                NaN            NaN
# 9              400000.0           -20.00              206.0            1.0
# 10             100000.0           300.00                NaN            NaN
# 11             550000.0           266.67               40.0            3.0
#
#    injury_proneness
# 4               NaN
# 8               NaN
# 9              0.33
# 10              NaN
# 11             1.00
#
# [5 rows x 48 columns]
#
# Basic statistics:
# ---------------------------------------------------------------------------
#
# KeyError                                  Traceback (most recent call last)
#
# Cell In[7], line 158
#
#     156 print(df.head())
#
#     157 print(f"\nBasic statistics:")
#
# --> 158 print(df[['current_market_value', 'goals', 'assists', 'age']].describe())
#
#
#
# File ~/ML-Group-M/.venv/lib/python3.13/site-packages/pandas/core/frame.py:4384, in DataFrame.__getitem__(self, key)
#
#    4382     if is_iterator(key):
#
#    4383         key = list(key)
#
# -> 4384     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#
#    4386 # take() does not accept boolean indexers
#
#    4387 if getattr(indexer, "dtype", None) == bool:
#
#
#
# File ~/ML-Group-M/.venv/lib/python3.13/site-packages/pandas/core/indexes/base.py:6302, in Index._get_indexer_strict(self, key, axis_name)
#
#    6299 else:
#
#    6300     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
#
# -> 6302 self._raise_if_missing(keyarr, indexer, axis_name)
#
#    6304 keyarr = self.take(indexer)
#
#    6305 if isinstance(key, Index):
#
#    6306     # GH 42790 - Preserve name from an Index
#
#
#
# File ~/ML-Group-M/.venv/lib/python3.13/site-packages/pandas/core/indexes/base.py:6355, in Index._raise_if_missing(self, key, indexer, axis_name)
#
#    6352     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#
#    6354 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#
# -> 6355 raise KeyError(f"{not_found} not in index")
#
#
#
# KeyError: "['age'] not in index"
