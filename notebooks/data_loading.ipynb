# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

players = pd.read_csv("../data/player_profiles.csv")
performances = pd.read_csv("../data/player_performances.zip", compression='zip')
market_values = pd.read_csv("../data/player_market_value.csv")
injuries = pd.read_csv("../data/player_injuries.csv")
teams = pd.read_csv("../data/team_details.csv")
transfers = pd.read_csv("../data/transfer_history.csv")
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_13860\3288450723.py:7: DtypeWarning: Columns (29,30,31,32) have mixed types. Specify dtype option on import or set low_memory=False.
#   players = pd.read_csv("../data/player_profiles.csv")

# %%
print("PLAYERS:")
print(players.columns.tolist())

print("\nPERFORMANCES:")
print(performances.columns.tolist())

print("\nMARKET VALUES:")
print(market_values.columns.tolist())

print("\nINJURIES:")
print(injuries.columns.tolist())

print("\nTEAMS:")
print(teams.columns.tolist())

print("\nTRANSFERS:")
print(transfers.columns.tolist())
# Out:
# PLAYERS:
# ['player_id', 'player_slug', 'player_name', 'player_image_url', 'name_in_home_country', 'date_of_birth', 'place_of_birth', 'country_of_birth', 'height', 'citizenship', 'is_eu', 'position', 'main_position', 'foot', 'current_club_id', 'current_club_name', 'joined', 'contract_expires', 'outfitter', 'social_media_url', 'player_agent_id', 'player_agent_name', 'contract_option', 'date_of_last_contract_extension', 'on_loan_from_club_id', 'on_loan_from_club_name', 'contract_there_expires', 'second_club_url', 'second_club_name', 'third_club_url', 'third_club_name', 'fourth_club_url', 'fourth_club_name', 'date_of_death']
#
# PERFORMANCES:
# ['player_id', 'season_name', 'competition_id', 'competition_name', 'team_id', 'team_name', 'nb_in_group', 'nb_on_pitch', 'goals', 'assists', 'own_goals', 'subed_in', 'subed_out', 'yellow_cards', 'second_yellow_cards', 'direct_red_cards', 'penalty_goals', 'minutes_played', 'goals_conceded', 'clean_sheets']
#
# MARKET VALUES:
# ['player_id', 'date_unix', 'value']
#
# INJURIES:
# ['player_id', 'season_name', 'injury_reason', 'from_date', 'end_date', 'days_missed', 'games_missed']
#
# TEAMS:
# ['club_id', 'club_slug', 'club_name', 'logo_url', 'country_name', 'season_id', 'competition_id', 'competition_slug', 'competition_name', 'club_division', 'source_url', '_last_modified_at']
#
# TRANSFERS:
# ['player_id', 'season_name', 'transfer_date', 'from_team_id', 'from_team_name', 'to_team_id', 'to_team_name', 'transfer_type', 'value_at_transfer', 'transfer_fee']

# %%
# JOIN KEY

PLAYER_ID = 'player_id'

# AGGREGATE PERFORMANCE DATA
# We filter for recent seasons (from 2010 onwards) to focus on relevant data and reduce noise from very old performances
def extract_start_year(season):
# we have some seasons in format like '08/09'
    if '/' in season:
        year = season.split('/')[0]
        year = int(year)
        
        if year <= 30:   
            return 2000 + year
        else:            
            return 1900 + year
    
    # and some formatted like '1975'
    elif season.isdigit():
        return int(season)
    
    else:
        return None

performances['season_start_year'] = performances['season_name'].apply(extract_start_year)

performances = performances[
    performances['season_start_year'] >= 2010
]


# Aggregate performance stats per player
performance_agg = performances.groupby(PLAYER_ID).agg({
    'nb_on_pitch': 'sum',
    'goals': 'sum',
    'assists': 'sum',
    'minutes_played': 'sum',
    'yellow_cards': 'sum',
    'direct_red_cards': 'sum',
}).reset_index()

# Create derived features
performance_agg['goals_per_90'] = (performance_agg['goals'] / performance_agg['minutes_played'] * 90).round(2)
performance_agg['assists_per_90'] = (performance_agg['assists'] / performance_agg['minutes_played'] * 90).round(2)
performance_agg['goal_contributions'] = performance_agg['goals'] + performance_agg['assists']

# Handle division by zero
performance_agg['goals_per_90'] = performance_agg['goals_per_90'].fillna(0)
performance_agg['assists_per_90'] = performance_agg['assists_per_90'].fillna(0)

# We rename columns for clarity
performance_agg = performance_agg.rename(columns={
    'nb_on_pitch': 'matches',
    'direct_red_cards': 'red_cards'
})


# GET LATEST MARKET VALUE
market_values['date'] = pd.to_datetime(
    market_values['date_unix'], unit='s'
)
market_values = market_values.sort_values('date')

# Get latest valuation per player
latest_values = (
    market_values
    .groupby(PLAYER_ID)
    .tail(1)
)

# Get first valuation per player
first_values = (
    market_values
    .groupby(PLAYER_ID)
    .head(1)
)

# Merge first and latest to compute growth
value_change = latest_values.merge(
    first_values[[PLAYER_ID, 'value']],
    on=PLAYER_ID,
    suffixes=('_latest', '_first'),
    how='left'
)

value_change['value_change_pct'] = (
    (value_change['value_latest'] - value_change['value_first']) /
    value_change['value_first'] * 100
).round(2)

# Attach value change to latest values
latest_values = latest_values.merge(
    value_change[[PLAYER_ID, 'value_change_pct']],
    on=PLAYER_ID,
    how='left'
)

# Rename target column
latest_values = latest_values.rename(
    columns={'value': 'current_market_value'})


# AGGREGATE INJURY DATA
injury_agg = injuries.groupby(PLAYER_ID).agg({
    'days_missed': 'sum',
    'injury_reason': 'count'
}).reset_index()

injury_agg = injury_agg.rename(columns={
    'days_missed': 'total_days_injured',
    'injury_reason': 'total_injuries'
})

# Create injury proneness score
injury_agg['injury_proneness'] = (injury_agg['total_injuries'] / 3).round(2)


# JOIN ALL DATAFRAMES
# Start with player profiles
df = players.copy()

# Join performance stats
df = df.merge(performance_agg, on=PLAYER_ID, how='left')

# Join market values (INNER JOIN - only keep players with valuations)
df = df.merge(
    latest_values[[PLAYER_ID, 'current_market_value', 'value_change_pct']], 
    on=PLAYER_ID, 
    how='inner'
)

# Join injury data
df = df.merge(injury_agg, on=PLAYER_ID, how='left')

# Fill missing injury data with 0
df['total_days_injured'] = df['total_days_injured'].fillna(0)
df['total_injuries'] = df['total_injuries'].fillna(0)
df['injury_proneness'] = df['injury_proneness'].fillna(0)

# Join team details
df = df.merge(
    teams[['club_id', 'competition_name', 'club_division']],
    left_on='current_club_id',
    right_on='club_id',
    how='left'
)

# Compute players age
today = pd.Timestamp.today()

df['date_of_birth'] = pd.to_datetime(df['date_of_birth'], errors='coerce')

df['age'] = (
    today.year - df['date_of_birth'].dt.year
    - (
        (today.month < df['date_of_birth'].dt.month) |
        (
            (today.month == df['date_of_birth'].dt.month) &
            (today.day < df['date_of_birth'].dt.day)
        )
    )
).astype('Int64')


# DATA CLEANING
# Define critical columns
critical_columns = ['current_market_value']
if 'age' in df.columns:
    critical_columns.append('age')
if 'position' in df.columns:
    critical_columns.append('position')

# Remove rows with missing critical data
df = df.dropna(subset=critical_columns)

# Remove players with zero market value
df = df[df['current_market_value'] > 0]

# Fill missing performance stats with 0
performance_cols = ['goals', 'assists', 'minutes_played', 'matches', 
                   'goals_per_90', 'assists_per_90', 'goal_contributions',
                   'yellow_cards', 'red_cards']

for col in performance_cols:
    if col in df.columns:
         df[col] = df[col].fillna(0)

# We drop columns that are not useful for modeling (like images, social media links, etc.)
cols_to_drop = [
    'player_slug',
    'player_image_url',
    'place_of_birth',
    'country_of_birth',
    'name_in_home_country',
    'social_media_url',
    'second_club_url',
    'third_club_url',
    'fourth_club_url',
    'player_agent_id',
    'player_agent_name'
]

df = df.drop(columns = cols_to_drop)

# SAVE DATASET
df.to_csv("player_valuation_dataset.csv", index=False)

# Display summary
print(f"Dataset created: {len(df):,} players × {len(df.columns)} columns")
print(f"\nSample data:")
print(df.head())
print(f"\nBasic statistics:")
print(df[['current_market_value', 'goals', 'assists', 'age']].describe())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File tslib.pyx:316, in pandas._libs.tslib.array_with_unit_to_datetime()
#
# ValueError: could not convert string to float: '2023-12-19'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 59
#      52 performance_agg = performance_agg.rename(columns={
#      53     'nb_on_pitch': 'matches',
#      54     'direct_red_cards': 'red_cards'
#      55 })
#      58 # GET LATEST MARKET VALUE
# ---> 59 market_values['date'] = pd.to_datetime(
#      60     market_values['date_unix'], unit='s'
#      61 )
#      62 market_values = market_values.sort_values('date')
#      64 # Get latest valuation per player
#
# File c:\Users\user\anaconda3\Lib\site-packages\pandas\core\tools\datetimes.py:1067, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1065         result = arg.map(cache_array)
#    1066     else:
# -> 1067         values = convert_listlike(arg._values, format)
#    1068         result = arg._constructor(values, index=arg.index, name=arg.name)
#    1069 elif isinstance(arg, (ABCDataFrame, abc.MutableMapping)):
#
# File c:\Users\user\anaconda3\Lib\site-packages\pandas\core\tools\datetimes.py:407, in _convert_listlike_datetimes(arg, format, name, utc, unit, errors, dayfirst, yearfirst, exact)
#     405     if format is not None:
#     406         raise ValueError("cannot specify both format and unit")
# --> 407     return _to_datetime_with_unit(arg, unit, name, utc, errors)
#     408 elif getattr(arg, "ndim", 1) > 1:
#     409     raise TypeError(
#     410         "arg must be a string, datetime, list, tuple, 1-d array, or Series"
#     411     )
#
# File c:\Users\user\anaconda3\Lib\site-packages\pandas\core\tools\datetimes.py:526, in _to_datetime_with_unit(arg, unit, name, utc, errors)
#     524     else:
#     525         arg = arg.astype(object, copy=False)
# --> 526         arr, tz_parsed = tslib.array_with_unit_to_datetime(arg, unit, errors=errors)
#     528 if errors == "ignore":
#     529     # Index constructor _may_ infer to DatetimeIndex
#     530     result = Index._with_infer(arr, name=name)
#
# File tslib.pyx:344, in pandas._libs.tslib.array_with_unit_to_datetime()
#
# File tslib.pyx:318, in pandas._libs.tslib.array_with_unit_to_datetime()
#
# ValueError: non convertible value 2023-12-19 with the unit 's', at position 0

# %%
print(df[['matches','goals','assists']].head())
# Out:
#     matches  goals  assists
# 4     401.0   44.0     35.0
# 8      62.0    2.0      4.0
# 9      43.0   10.0      2.0
# 10     60.0    8.0      0.0
# 11    107.0   21.0     18.0

# %% [markdown]
# ## PCA Analysis

# %%
df = pd.read_csv("player_valuation_dataset.csv")

print(df.shape)
df.head()
# Out:
# (33557, 41)
# C:\Users\user\AppData\Local\Temp\ipykernel_13860\689054395.py:1: DtypeWarning: Columns (22) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("player_valuation_dataset.csv")
#    player_id                   player_name date_of_birth  height  \
# 0     100001        Carlos Auzqui (100001)    1991-03-16   180.0
# 1    1000274        Brian Romero (1000274)    2006-05-11     0.0
# 2    1000273  Nimfasha Berchimas (1000273)    2008-02-22   172.0
# 3    1000135        Joselu Pérez (1000135)    2004-03-12   183.0
# 4    1000284            Jed Drew (1000284)    2003-08-29   176.0
#
#               citizenship  is_eu                 position main_position  \
# 0               Argentina  False    Attack - Right Winger        Attack
# 1   United States  Mexico  False    Attack - Right Winger        Attack
# 2  United States  Burundi  False     Attack - Left Winger        Attack
# 3                   Spain   True  Attack - Centre-Forward        Attack
# 4               Australia  False    Attack - Right Winger        Attack
#
#     foot  current_club_id  ... goal_contributions current_market_value  \
# 0  right            14554  ...               79.0             200000.0
# 1    NaN            78435  ...                6.0             150000.0
# 2  right            78435  ...               12.0             400000.0
# 3  right             8510  ...                8.0             100000.0
# 4  right             4467  ...               39.0             550000.0
#
#   value_change_pct total_days_injured total_injuries injury_proneness  \
# 0           100.00                0.0            0.0             0.00
# 1             0.00                0.0            0.0             0.00
# 2           -20.00              206.0            1.0             0.33
# 3           300.00                0.0            0.0             0.00
# 4           266.67               40.0            3.0             1.00
#
#    club_id     competition_name        club_division age
# 0  14554.0      Torneo Clausura      Torneo Clausura  34
# 1  78435.0  Major League Soccer  Major League Soccer  19
# 2  78435.0  Major League Soccer  Major League Soccer  18
# 3      NaN                  NaN                  NaN  21
# 4   4467.0           Bundesliga           Bundesliga  22
#
# [5 rows x 41 columns]

# %%
numeric_df = df.select_dtypes(include=[np.number]).copy()

print("Number of numeric features:", numeric_df.shape[1])
# Out:
# Number of numeric features: 21

# %%
cols_to_exclude = [
    'player_id',
    'current_club_id',
    'club_id',
    'current_market_value'  # target-like variable
]

X = numeric_df.drop(columns=[col for col in cols_to_exclude if col in numeric_df.columns], errors='ignore')

# %%
# remove constant columns
X = X.loc[:, X.nunique() > 1]

# fill missing values
X = X.fillna(0)

# %%
# Keep only true numeric columns
X = X.select_dtypes(include=[np.number]).copy()

# Replace inf values with NaN, then fill
X = X.replace([np.inf, -np.inf], np.nan)
X = X.fillna(0)

# check data types
print(X.dtypes.value_counts())
print(X.shape)
# Out:
# float64    15
# int64       1
# Name: count, dtype: int64
# (33557, 16)

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
pca = PCA()
X_pca = pca.fit_transform(X_scaled)

explained_variance = pca.explained_variance_ratio_
cumulative_variance = explained_variance.cumsum()

pca_summary = pd.DataFrame({
    'PC': [f'PC{i+1}' for i in range(len(explained_variance))],
    'Explained Variance': explained_variance,
    'Cumulative Variance': cumulative_variance
})

pca_summary.head(10)
# Out:
#      PC  Explained Variance  Cumulative Variance
# 0   PC1            0.347256             0.347256
# 1   PC2            0.152329             0.499585
# 2   PC3            0.104948             0.604533
# 3   PC4            0.063601             0.668134
# 4   PC5            0.061562             0.729697
# 5   PC6            0.059786             0.789483
# 6   PC7            0.055634             0.845117
# 7   PC8            0.042704             0.887821
# 8   PC9            0.035238             0.923059
# 9  PC10            0.023946             0.947004

# %%
# FIND NUMBER OF COMPONENTS FOR 80% AND 90%

n_components_80 = np.argmax(cumulative_variance >= 0.80) + 1
n_components_90 = np.argmax(cumulative_variance >= 0.90) + 1

print("Number of components explaining at least 80% variance:", n_components_80)
print("Number of components explaining at least 90% variance:", n_components_90)
# Out:
# Number of components explaining at least 80% variance: 7
# Number of components explaining at least 90% variance: 9

# %%
plt.figure(figsize=(8,5))
plt.plot(range(1, len(explained_variance)+1), explained_variance, marker='o')
plt.xlabel("Principal Component")
plt.ylabel("Explained Variance Ratio")
plt.title("Scree Plot")
plt.grid(True)
plt.show()

# %%
#CUMULATIVE EXPLAINED VARIANCE PLOT
plt.figure(figsize=(8,5))
plt.plot(range(1, len(cumulative_variance)+1), cumulative_variance, marker='o')
plt.axhline(y=0.80, linestyle='--')
plt.axhline(y=0.90, linestyle='--')
plt.xlabel("Principal Component")
plt.ylabel("Cumulative Explained Variance")
plt.title("Cumulative Explained Variance")
plt.grid(True)
plt.show()

# %%
pca_final = PCA(n_components=0.90)  # keep 90% variance
X_reduced = pca_final.fit_transform(X_scaled)

print("Original shape:", X.shape)
print("Reduced shape:", X_reduced.shape)
print("Number of components kept:", pca_final.n_components_)
# Out:
# Original shape: (33557, 16)
# Reduced shape: (33557, 9)
# Number of components kept: 9

# %%
loadings = pd.DataFrame(
    pca_final.components_.T,
    columns=[f'PC{i+1}' for i in range(pca_final.n_components_)],
    index=X.columns
)

loadings.head()
# Out:
#                            PC1       PC2       PC3       PC4       PC5  \
# height                0.111637 -0.110639 -0.029968  0.426349  0.224188
# on_loan_from_club_id -0.044127  0.049644  0.015702 -0.361290  0.919250
# matches               0.376151 -0.135193 -0.225192  0.045063  0.024576
# goals                 0.311003  0.347380 -0.123474  0.017297 -0.000478
# assists               0.332056  0.217454 -0.088410  0.038636  0.002803
#
#                            PC6       PC7       PC8       PC9
# height               -0.507913  0.670304 -0.043349 -0.159613
# on_loan_from_club_id -0.075171 -0.114635  0.020977 -0.002555
# matches              -0.010435 -0.134122  0.046581  0.029906
# goals                -0.037696 -0.058060 -0.349462 -0.040997
# assists               0.017511 -0.166538  0.175390 -0.487638

# %%
loadings['PC1'].abs().sort_values(ascending=False).head(10)
# Out:
# matches               0.376151
# goal_contributions    0.342586
# assists               0.332056
# goals                 0.311003
# total_injuries        0.308970
# injury_proneness      0.308968
# age                   0.305713
# yellow_cards          0.296384
# total_days_injured    0.223472
# minutes_played        0.184837
# Name: PC1, dtype: float64

# %%
# Show how much variance each PC explains
print(pca_summary.head(10))

# Key interpretation values
total_variance_80 = np.argmax(cumulative_variance >= 0.80) + 1
total_variance_90 = np.argmax(cumulative_variance >= 0.90) + 1

print(f"Number of components to explain 80% variance: {total_variance_80}")
print(f"Number of components to explain 90% variance: {total_variance_90}")
# Out:
#      PC  Explained Variance  Cumulative Variance
# 0   PC1            0.347256             0.347256
# 1   PC2            0.152329             0.499585
# 2   PC3            0.104948             0.604533
# 3   PC4            0.063601             0.668134
# 4   PC5            0.061562             0.729697
# 5   PC6            0.059786             0.789483
# 6   PC7            0.055634             0.845117
# 7   PC8            0.042704             0.887821
# 8   PC9            0.035238             0.923059
# 9  PC10            0.023946             0.947004
# Number of components to explain 80% variance: 7
# Number of components to explain 90% variance: 9

# %%
# 2D PCA projection
pca_2 = PCA(n_components=2)
X_pca_2 = pca_2.fit_transform(X_scaled)

plt.figure()
plt.scatter(X_pca_2[:,0], X_pca_2[:,1], alpha=0.6)
plt.xlabel("PC1")
plt.ylabel("PC2")
plt.title("Players projected on first two principal components")
plt.grid()
plt.show()

# %% [markdown]
# PCA was used to reduce the dimensionality of the player valuation dataset while preserving as much information as possible.
#
# Since the variables were measured on different scales, the data was standardized before applying PCA.
#
# The results showed that the first principal components explained a large proportion of the total variance, meaning that the original dataset can be summarized with fewer dimensions.
#
# The scree plot and cumulative explained variance confirmed that only a limited number of components were needed to retain most of the information. By examining the loadings, it was also possible to identify which original variables contributed most strongly to the first components.
#
# Overall, PCA simplified the structure of the dataset and created a reduced representation that can be useful for later modeling or clustering.

# %% [markdown]
# ## Feature Engineering

# %%
#df["contract_expires"].to_timestamp(axis=1)

#df["years_under_contract"] = pd.Timestamp(df["contract_expires"]) - pd.Timestamp.now()
#df["contract_expires"].head()
#df["years_under_contract"].head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 df["contract_expires"].to_timestamp(axis=1)
#
# TypeError: Series.to_timestamp() got an unexpected keyword argument 'axis'
