# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os 
print(os.getcwd())
# Out:
# c:\Users\morga\OneDrive\Ambiente de Trabalho\Universidade\Mestrado\S2 T3\Machine Learning\ML-Group-M\data

# %%
players = pd.read_csv("player_profiles.csv")
performances = pd.read_csv("player_performances.zip", compression='zip')
market_values = pd.read_csv("player_market_value.csv")
injuries = pd.read_csv("player_injuries.csv")
teams = pd.read_csv("team_details.csv")
transfers = pd.read_csv("transfer_history.csv")
# Out:
# C:\Users\morga\AppData\Local\Temp\ipykernel_29132\463606308.py:1: DtypeWarning: Columns (29,30,31,32) have mixed types. Specify dtype option on import or set low_memory=False.
#   players = pd.read_csv("player_profiles.csv")
