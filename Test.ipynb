# %%
from data_loading import data_loading
from data_cleaning import data_cleaning
from feature_engineering import feature_engineering

df = data_loading()
clean_df = data_cleaning(df)
enhanced_df = feature_engineering(clean_df)
# Out:
# Raw injuries rows: 143195
# Raw injuries missing days: 22
# c:\Users\user\Desktop\GitHub\GitHub Repos\ML-Group-M\feature_engineering.py:281: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df["net_per_90_normalized"] = df.groupby("main_position")["net_per_90"].transform(
# c:\Users\user\Desktop\GitHub\GitHub Repos\ML-Group-M\feature_engineering.py:290: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df["goal_contributions_normalized"] = df.groupby("main_position")["goal_contributions"].transform(

# %%
# Display summary
print(f"Dataset created: {len(enhanced_df):,} players × {len(enhanced_df.columns)} columns")
print(f"\nSample data:")
print(enhanced_df.head())
print(f"\nBasic statistics:")
print(enhanced_df[['current_market_value', 'goals', 'assists', 'age']].describe())
# Out:
# Dataset created: 33,557 players × 54 columns
#
# Sample data:
#     player_id                   player_name date_of_birth  height  \
# 4      100001        Carlos Auzqui (100001)    1991-03-16   180.0
# 8     1000274        Brian Romero (1000274)    2006-05-11     0.0
# 9     1000273  Nimfasha Berchimas (1000273)    2008-02-22   172.0
# 10    1000135        Joselu Pérez (1000135)    2004-03-12   183.0
# 11    1000284            Jed Drew (1000284)    2003-08-29   176.0
#
#                citizenship  is_eu                 position main_position  \
# 4                Argentina  False    Attack - Right Winger        Attack
# 8    United States  Mexico  False    Attack - Right Winger        Attack
# 9   United States  Burundi  False     Attack - Left Winger        Attack
# 10                   Spain   True  Attack - Centre-Forward        Attack
# 11               Australia  False    Attack - Right Winger        Attack
#
# ...
